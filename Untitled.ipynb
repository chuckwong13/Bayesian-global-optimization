# %% [markdown]
# Manual grid search: works for low-dimensional problems, but does not scale wll to higher dimensions;
# Random grid search: there is no guarantee...;
# Bayesian optimization: suitable for high number of hyperparameters and it's very expensive to evaluate a data point.

# %% [markdown]
# Instead of returning a scalar $f(x)$, a GP returns the mean and variance of a normal distribution over the possible values of $f$ at $x$.
# Firstly, we assume a Gaussian process prior $f(x)\sim GP(m(x),k(x,x^\prime))$, with noise $\epsilon \sim N(0,\sigma
# ^2)$ it becomes $y \sim GP(m(x),k(x,x^\prime)+\sigma_n^2\delta_{ij})$. So we can write the joint Gaussian distribution in this way:
# $$ \begin{bmatrix} y \\ f_* \\ \end{bmatrix} \sim N\left( \begin{bmatrix} u \\ u_* \\ \end{bmatrix},  \begin{bmatrix} K(X,X)+\sigma^2I & K(X,X_*) \\ K(X_*,X) & K(X_*,X_*) \\ \end{bmatrix}  \right)$$
# Here $K$ is the covariance kernel matrix. We can choose different kernel function to calculate it, e.g. squared exponential function.
# $$k(x_i,x_j)=\sigma_f^2 exp \left( -{1\over 2l^2} ||x_i-x_j||^2 \right)$$
# So the new predictive distribution is:
# $$f_* \mid X,y,X_* \sim N(\hat{f}_*, \Sigma_*)  $$
# $$\hat{f}_*=u_*+K(X_*,X)[K(X,X)+\sigma_n^2I]^{-1}(y-u)$$
# $$\Sigma_*=K(X_*,X_*)-K(X_*,X)[K(X,X)+\Sigma_n^2I]^{-1}K(X,X_*)$$

# %% [markdown]
# Acquisition functions are used to formalize what constitutes a "best guess".

# %%
import matplotlib.pyplot as plt
from PIL import Image
gp_example = Image.open("Annotation 2020-05-05 010508.png")
plt.subplots(figsize=(15,10))
plt.imshow(gp_example)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import numpy as np

np.random.seed(1)

def f(x):
    #true function
    return x * np.cos(x)

X = np.atleast_2d([1., 3., 5., 6., 7., 8.]).T

# Observations
y = f(X).ravel()

# Mesh the input space for evaluations of the real function, the prediction and
# its MSE
x = np.atleast_2d(np.linspace(0, 10, 1000)).T

# Instantiate a Gaussian Process model
kernel = C(1.0, (1e-3, 1e3)) * RBF(1, (1e-2, 1e2))# covariance function
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(x, return_std=True)

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
plt.subplots(figsize=(15,10))
plt.plot(x, f(x), 'r:', label=r'$f(x)$')
plt.plot(X, y, 'r.', markersize=10, label='Observations')
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate([y_pred - 1.9600 * sigma,
                        (y_pred + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend()

# %% [markdown]
# 05/14

# %%
import bayesian_optimization_util
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c913c02abee7> in <module>
# ----> 1 import bayesian_optimization_util
#
# ModuleNotFoundError: No module named 'bayesian_optimization_util'
